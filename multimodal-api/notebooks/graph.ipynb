# %%
# %load_ext autoreload
# %autoreload 2

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from multimodal_api.agent.graph import graph
# Out:
# E:\python projects\multi-modal-rag\multimodal-api\src\multimodal_api\agent\graph.py:19: UserWarning: The 'config' parameter should be typed as 'RunnableConfig' or 'RunnableConfig | None', not 'typing.Any'.
#   graph_builder.add_node("tool_executor_node", tool_executor_node)

# %%
from IPython.display import display, Image

display(Image(graph.get_graph().draw_mermaid_png()))
