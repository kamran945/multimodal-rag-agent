# %%
# %load_ext autoreload
# %autoreload 2

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from pathlib import Path

from multimodal_mcp.video.search_video import VideoSearchEngine

video_path = "./data/pass_the_butter_rick_and_morty.mp4"
video_name = Path(video_path).stem

video_search_engine = VideoSearchEngine()
# Out:
# 2025-10-31 15:33:46.925 | INFO     | multimodal_mcp.video.search_video:__init__:39 - Initializing VideoSearchEngine...'
# 2025-10-31 15:33:46.967 | INFO     | multimodal_mcp.video.search_video:__init__:73 - ✅ Loaded video search context for user query...

# %%
speech_results = video_search_engine.search_by_speech("talk about science project", top_k=1)
speech_results
# Out:
# [{'start_time': 0.0, 'end_time': 10.0693, 'similarity': 0.5287090259020949}]

# %%
from multimodal_mcp.video.ingestion.tools import encode_image

sad_robot_image = "./data/sad_robot.png"
sad_robot_base64 = encode_image(image=sad_robot_image)

image_results = video_search_engine.search_by_image(sad_robot_base64, top_k=3)
image_results
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# [{'start_time': 52.89116666666666,
#   'end_time': 62.89116666666666,
#   'similarity': 0.9203061238273721},
#  {'start_time': 34.60623333333333,
#   'end_time': 44.60623333333333,
#   'similarity': 0.8130490775527157},
#  {'start_time': 46.785066666666665,
#   'end_time': 56.785066666666665,
#   'similarity': 0.798989435257986}]

# %%
caption_results = video_search_engine.search_by_caption("a robot in the picture", top_k=1)
caption_results
# Out:
# [{'start_time': 52.89116666666666,
#   'end_time': 62.89116666666666,
#   'similarity': 0.7307093578999865}]

# %%
speech_info = video_search_engine.get_speech_info("What is my purpose?", top_k=2)
speech_info
# Out:
# [{'text': 'What is my purpose? Pass the butter. Thank you.',
#   'similarity': 0.6466733409963057},
#  {'text': "with science. I'm busy. Doing what? Anything else? What is my purpose? You pass butter.",
#   'similarity': 0.5201763069682215}]

# %%
caption_info = video_search_engine.get_caption_info("holding a tablet", top_k=2)
caption_info
# Out:
# [{'caption': 'The image shows a still from the animated television series Rick and Morty. \n\nThe image features two characters: A boy with short brown hair and a yellow shirt on the left; A man with short brown hair and a green polo shirt on the right. The man on the right is holding a tablet. They are sitting at a table with a green and white checkered tablecloth, a plate of pancakes, two glasses of orange juice, a butter knife, and a butter. The man on the right is looking at the tablet with a sad or upset expression, while the boy on the left is looking at him with a concerned expression, with his hand on his chin. \n\nThe background shows a window with a pink curtain on the right; a wall with a picture frame showing yellow flowers. Outside the window, there are houses and trees. The overall atmosphere suggests that the characters are having a conversation or reacting to something on the tablet.',
#   'similarity': 0.3479102551937103},
# ...
