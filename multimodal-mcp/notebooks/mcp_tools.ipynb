# %%
# %load_ext autoreload
# %autoreload 2

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from pathlib import Path

video_path = "./data/pass_the_butter_rick_and_morty.mp4"
video_name = Path(video_path).stem

# %%
from multimodal_mcp.tools import (process_video,
                                  get_video_clip_from_user_query,
                                  get_video_clip_from_image,
                                  ask_question_about_video)
# Out:
# <frozen importlib._bootstrap>:241: DeprecationWarning: builtin type SwigPyPacked has no __module__ attribute
# <frozen importlib._bootstrap>:241: DeprecationWarning: builtin type SwigPyObject has no __module__ attribute
# <frozen importlib._bootstrap>:241: DeprecationWarning: builtin type swigvarlink has no __module__ attribute
# Connected to Pixeltable database at: postgresql+psycopg://postgres:@127.0.0.1:57001/pixeltable

# %%
process_video(video_path)
# Out:
# 2025-10-31 15:45:11.452 | INFO     | multimodal_mcp.tools:process_video:34 - Starting processing for './data/pass_the_butter_rick_and_morty.mp4'...
# 2025-10-31 15:45:11.494 | INFO     | multimodal_mcp.video.ingestion.video_processor:add_video:133 - ⚠️ Video 'pass_the_butter_rick_and_morty' already processed. Skipping.
# False

# %%
from IPython.display import HTML

video_clip = get_video_clip_from_user_query(user_query="show me the one with the robot")

HTML(f"""
<video width="480" controls>
  <source src="{video_clip}" type="video/mp4">
  Your browser does not support the video tag.
</video>
""")
# Out:
# 2025-10-31 15:45:23.476 | INFO     | multimodal_mcp.video.search_video:__init__:39 - Initializing VideoSearchEngine...'
# 2025-10-31 15:45:23.512 | INFO     | multimodal_mcp.video.search_video:__init__:73 - ✅ Loaded video search context for user query...
# 2025-10-31 15:45:30.481 | DEBUG    | multimodal_mcp.video.ingestion.tools:extract_video_clip:53 - FFmpeg output:
# 2025-10-31 15:45:33.979 | SUCCESS  | multimodal_mcp.tools:get_video_clip_from_user_query:82 - Extracted clip → ././shared_media/8a2f982e-0e67-43e1-a1ed-fdacbf861cae.mp4
# <video width="480" controls>
#   <source src="././shared_media/8a2f982e-0e67-43e1-a1ed-fdacbf861cae.mp4" type="video/mp4">
#   Your browser does not support the video tag.
# </video>

# %%
from multimodal_mcp.video.ingestion.tools import encode_image

sad_robot_image = "./data/sad_robot.png"
sad_robot_base64 = encode_image(image=sad_robot_image)

video_clip = get_video_clip_from_image(image_base64=sad_robot_base64)

HTML(f"""
<video width="480" controls>
  <source src="{video_clip}" type="video/mp4">
  Your browser does not support the video tag.
</video>
""")
# Out:
# 2025-10-31 15:45:54.032 | INFO     | multimodal_mcp.video.search_video:__init__:39 - Initializing VideoSearchEngine...'
# 2025-10-31 15:45:54.086 | INFO     | multimodal_mcp.video.search_video:__init__:73 - ✅ Loaded video search context for user query...
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# 2025-10-31 15:46:00.646 | DEBUG    | multimodal_mcp.video.ingestion.tools:extract_video_clip:53 - FFmpeg output:
# 2025-10-31 15:46:04.548 | SUCCESS  | multimodal_mcp.tools:get_video_clip_from_image:122 - Extracted clip from image query → ././shared_media/e80c7e66-0def-4246-8503-7d1ed7f9f8d2.mp4
# <video width="480" controls>
# ...

# %%
response = ask_question_about_video(user_query="when they were eating")
response
# Out:
# 2025-10-31 15:47:31.053 | INFO     | multimodal_mcp.video.search_video:__init__:39 - Initializing VideoSearchEngine...'
# 2025-10-31 15:47:31.097 | INFO     | multimodal_mcp.video.search_video:__init__:73 - ✅ Loaded video search context for user query...
# 2025-10-31 15:47:31.226 | INFO     | multimodal_mcp.tools:ask_question_about_video:153 - Answer extracted: → 3 captions.
# ...
